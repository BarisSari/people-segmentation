# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import cv2
import mrcnn.config
import mrcnn.visualize as visualize
import mrcnn.utils
from mrcnn.model import MaskRCNN
from pathlib import Path
from matplotlib import pyplot as plt

# Configuration that will be used by the Mask-RCNN library
class MaskRCNNConfig(mrcnn.config.Config):
    NAME = "coco_pretrained_model_config"
    IMAGES_PER_GPU = 3
    GPU_COUNT = 1
    NUM_CLASSES = 1 + 80  # COCO dataset has 80 classes + one background class

# %%
class_names = ['BG', 'person', 'bicycle', 'car', 'motorcycle', 'airplane',
               'bus', 'train', 'truck', 'boat', 'traffic light',
               'fire hydrant', 'stop sign', 'parking meter', 'bench', 'bird',
               'cat', 'dog', 'horse', 'sheep', 'cow', 'elephant', 'bear',
               'zebra', 'giraffe', 'backpack', 'umbrella', 'handbag', 'tie',
               'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball',
               'kite', 'baseball bat', 'baseball glove', 'skateboard',
               'surfboard', 'tennis racket', 'bottle', 'wine glass', 'cup',
               'fork', 'knife', 'spoon', 'bowl', 'banana', 'apple',
               'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza',
               'donut', 'cake', 'chair', 'couch', 'potted plant', 'bed',
               'dining table', 'toilet', 'tv', 'laptop', 'mouse', 'remote',
               'keyboard', 'cell phone', 'microwave', 'oven', 'toaster',
               'sink', 'refrigerator', 'book', 'clock', 'vase', 'scissors',
               'teddy bear', 'hair drier', 'toothbrush']

# %%
# Root directory of the project
ROOT_DIR = Path(".")

# Directory to save logs and trained model
MODEL_DIR = os.path.join(ROOT_DIR, "logs")

# Local path to trained weights file
COCO_MODEL_PATH = os.path.join(ROOT_DIR, "mask_rcnn_coco.h5")

# Download COCO trained weights from Releases if needed
if not os.path.exists(COCO_MODEL_PATH):
    mrcnn.utils.download_trained_weights(COCO_MODEL_PATH)

# Directory of images to run detection on
IMAGE_DIR = os.path.join(ROOT_DIR, "images")

# Create a Mask-RCNN model in inference mode
model = MaskRCNN(mode="inference", model_dir=MODEL_DIR, config=MaskRCNNConfig())

# %%
def get_ax(rows=1, cols=1, size=32):
    """Return a Matplotlib Axes array to be used in
    all visualizations in the notebook. Provide a
    central point to control graph sizes.
    
    Adjust the size attribute to control how big to render images
    """
    _, ax = plt.subplots(rows, cols, figsize=(size*cols, size*rows))
    return ax

# %%
# Load pre-trained model
model.load_weights(COCO_MODEL_PATH, by_name=True)

# %%
for i in range(0, 1):

    filename = str(i).zfill(5) + ".jpg"
    # Load the image we want to run detection on
    image_path = str(ROOT_DIR / "DAVIS" / "JPEGImages" / "480p" / "subway" / filename)
    image = cv2.imread(image_path)
    # Convert the image from BGR color (which OpenCV uses) to RGB color
#     rgb_image = image[:, :, ::-1]

    # Run the image through the model
    results = model.detect([image], verbose=1)
    # print(i)
    # Visualize results
    r = results[0]
    visualize.display_instances(image, r['rois'], r['masks'], r['class_ids'], 
                            class_names, r['scores'], show_mask=False, show_bbox=True)
# Out:
# Processing 1 images
# image                    shape: (480, 854, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# /home/Vlad/BARIS/topic-modeling/newenv/lib/python3.6/site-packages/skimage/transform/_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "

# %%
image_path = str(ROOT_DIR / "val2017" / "0000.jpg")
image = cv2.imread(image_path)
# Get input and output to classifier and mask heads.
mrcnn_ = model.run_graph([image], [
    ("proposals", model.keras_model.get_layer("ROI").output),
    ("probs", model.keras_model.get_layer("mrcnn_class").output),
    ("deltas", model.keras_model.get_layer("mrcnn_bbox").output),
    ("masks", model.keras_model.get_layer("mrcnn_mask").output),
    ("detections", model.keras_model.get_layer("mrcnn_detection").output),
])
# Out:
# proposals                shape: (1, 1000, 4)          min:    0.00000  max:    1.00000  float32
# probs                    shape: (1, 1000, 81)         min:    0.00000  max:    0.99976  float32
# deltas                   shape: (1, 1000, 81, 4)      min:   -3.78622  max:    3.53204  float32
# masks                    shape: (1, 100, 28, 28, 81)  min:    0.00000  max:    0.99998  float32
# detections               shape: (1, 100, 6)           min:    0.00000  max:   76.00000  float32

# %%
det_class_ids = mrcnn_['detections'][0, :, 4].astype(np.int32)
det_count = np.where(det_class_ids == 0)[0][0]
det_class_ids = det_class_ids[:det_count]
detections = mrcnn_['detections'][0, :det_count]
print("{} detections: {}".format(
    det_count, np.array(class_names)[det_class_ids]))

captions = ["{} {:.3f}".format(class_names[int(c)], s) if c > 0 else ""
            for c, s in zip(detections[:, 4], detections[:, 5])]
visualize.draw_boxes(
    image, 
    refined_boxes=detections[:, :4],
    visibilities=[2] * len(detections),
    captions=captions, title="Detections",
    ax=get_ax())
plt.imsave('test.jpg', test)
# Out:
# 19 detections: ['tv' 'chair' 'chair' 'tv' 'chair' 'potted plant' 'vase' 'refrigerator'
#  'vase' 'dining table' 'dining table' 'clock' 'cup' 'person' 'vase' 'cup'
#  'potted plant' 'dining table' 'vase']
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-c48bd03fa8b0> in <module>
#      14     captions=captions, title="Detections",
#      15     ax=get_ax())
# ---> 16 plt.imsave('test.jpg', test)
#
# ~/BARIS/topic-modeling/newenv/lib/python3.6/site-packages/matplotlib/pyplot.py in imsave(fname, arr, **kwargs)
#    2155 @docstring.copy_dedent(matplotlib.image.imsave)
#    2156 def imsave(fname, arr, **kwargs):
# -> 2157     return matplotlib.image.imsave(fname, arr, **kwargs)
#    2158
#    2159
#
# ~/BARIS/topic-modeling/newenv/lib/python3.6/site-packages/matplotlib/image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi)
#    1431         FigureCanvas(fig)
#    1432         fig.figimage(arr, cmap=cmap, vmin=vmin, vmax=vmax, origin=origin,
# -> 1433                      resize=True)
#    1434         fig.savefig(fname, dpi=dpi, format=format, transparent=True)
#    1435
#
# ~/BARIS/topic-modeling/newenv/lib/python3.6/site-packages/matplotlib/figure.py in figimage(self, X, xo, yo, alpha, norm, cmap, vmin, vmax, origin, resize, **kwargs)
#     854         if resize:
#     855             dpi = self.get_dpi()
# --> 856             figsize = [x / dpi for x in (X.shape[1], X.shape[0])]
#     857             self.set_size_inches(figsize, forward=True)
#     858
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
from pycocotools.coco import COCO
dataset = COCO.CocoDataset()
dataset.load_coco(COCO_DIR, "minival")

dataDir='..'
dataType='val2017'
annFile='{}/annotations/instances_{}.json'.format(dataDir,dataType)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-d7171d173ecc> in <module>
# ----> 1 from pycocotools.coco import COCO
#       2 dataset = COCO.CocoDataset()
#       3 dataset.load_coco(COCO_DIR, "minival")
#       4
#       5 dataDir='..'
#
# ModuleNotFoundError: No module named 'pycocotools'

# %%
# Must call before using the dataset
dataset.prepare()
image_id = np.random.choice(dataset.image_ids)
image, image_meta, gt_bbox, gt_mask =\
    modellib.load_image_gt(dataset, config, image_id, use_mini_mask=False)
info = dataset.image_info[image_id]
print("image ID: {}.{} ({}) {}".format(info["source"], info["id"], image_id, 
                                       dataset.image_reference(image_id)))
gt_class_id = gt_bbox[:, 4]

# Run object detection
results = model.detect([image], verbose=1)

# Display results
ax = get_ax(1)
r = results[0]
# visualize.display_instances(image, gt_bbox[:,:4], gt_mask, gt_bbox[:,4], 
#                             dataset.class_names, ax=ax[0], title="Ground Truth")
visualize.display_instances(image, r['rois'], r['masks'], r['class_ids'], 
                            dataset.class_names, r['scores'], ax=ax,
                            title="Predictions")
log("gt_class_id", gt_class_id)
log("gt_bbox", gt_bbox)
log("gt_mask", gt_mask)

# %%
image_path = str(ROOT_DIR / "DAVIS" / "JPEGImages" / "480p" / "subway" / "00000.jpg")
image = cv2.imread(image_path)
target_rpn_match, target_rpn_bbox = modellib.build_rpn_targets(
    image.shape, model.anchors, gt_bbox, model.config)
log("target_rpn_match", target_rpn_match)
log("target_rpn_bbox", target_rpn_bbox)

positive_anchor_ix = np.where(target_rpn_match[:] == 1)[0]
negative_anchor_ix = np.where(target_rpn_match[:] == -1)[0]
neutral_anchor_ix = np.where(target_rpn_match[:] == 0)[0]
positive_anchors = model.anchors[positive_anchor_ix]
negative_anchors = model.anchors[negative_anchor_ix]
neutral_anchors = model.anchors[neutral_anchor_ix]
log("positive_anchors", positive_anchors)
log("negative_anchors", negative_anchors)
log("neutral anchors", neutral_anchors)

# Apply refinement deltas to positive anchors
refined_anchors = utils.apply_box_deltas(
    positive_anchors,
    target_rpn_bbox[:positive_anchors.shape[0]] * model.config.RPN_BBOX_STD_DEV)
log("refined_anchors", refined_anchors, )

# %%
import model as modellib
# Generate RPN trainig targets
# target_rpn_match is 1 for positive anchors, -1 for negative anchors
# and 0 for neutral anchors.
target_rpn_match, target_rpn_bbox = modellib.build_rpn_targets(
    image.shape, model.anchors, gt_bbox, model.config)
log("target_rpn_match", target_rpn_match)
log("target_rpn_bbox", target_rpn_bbox)

positive_anchor_ix = np.where(target_rpn_match[:] == 1)[0]
negative_anchor_ix = np.where(target_rpn_match[:] == -1)[0]
neutral_anchor_ix = np.where(target_rpn_match[:] == 0)[0]
positive_anchors = model.anchors[positive_anchor_ix]
negative_anchors = model.anchors[negative_anchor_ix]
neutral_anchors = model.anchors[neutral_anchor_ix]
log("positive_anchors", positive_anchors)
log("negative_anchors", negative_anchors)
log("neutral anchors", neutral_anchors)

# Apply refinement deltas to positive anchors
refined_anchors = utils.apply_box_deltas(
    positive_anchors,
    target_rpn_bbox[:positive_anchors.shape[0]] * model.config.RPN_BBOX_STD_DEV)
log("refined_anchors", refined_anchors, )

# %%
image_path = str(ROOT_DIR / "DAVIS" / "JPEGImages" / "480p" / "subway" / "00000.jpg")
image = cv2.imread(image_path)
plt.imshow(image)
plt.show()
# Get input and output to classifier and mask heads.
mrcnn = model.run_graph([image], [
    ("proposals", model.keras_model.get_layer("ROI").output),
    ("probs", model.keras_model.get_layer("mrcnn_class").output),
    ("deltas", model.keras_model.get_layer("mrcnn_bbox").output),
    ("masks", model.keras_model.get_layer("mrcnn_mask").output),
    ("detections", model.keras_model.get_layer("mrcnn_detection").output),
])

# %%
# Get detection class IDs. Trim zero padding.
det_class_ids = mrcnn['detections'][0, :, 4].astype(np.int32)
print(np.where(det_class_ids==0)[0])
# det_count = np.where(det_class_ids == 0)[0][0]
# det_class_ids = det_class_ids[:det_count]
# detections = mrcnn['detections'][0, :det_count]

# print("{} detections: {}".format(
#     det_count, np.array(dataset.class_names)[det_class_ids]))

# captions = ["{} {:.3f}".format(dataset.class_names[int(c)], s) if c > 0 else ""
#             for c, s in zip(detections[:, 4], detections[:, 5])]
# visualize.draw_boxes(
#     image, 
#     refined_boxes=detections[:, :4],
#     visibilities=[2] * len(detections),
#     captions=captions, title="Detections",
#     ax=get_ax())

# %%
# !ls
# Out:
# 02_generate_person_masks.py   new_video.avi
# DAVIS			      output
# DAVIS-2017-test-dev-480p.zip  people-segmentation_on_images.ipynb
# file_from_ios.mov	      people_segmentation_on_videos.ipynb
# input_video.MOV		      people_segmentation_on_videos.py
# kiev_video.mp4		      result.avi
# logs			      Untitled.ipynb
# mask_rcnn_coco.h5	      val2017
# new_video2.avi		      video.mpg
# new_video3.avi

# %%
def random_colors(N):
    np.random.seed(1)
    colors = [tuple(255 * np.random.rand(3)) for _ in range(N)]
    return colors

def display_instances(image, boxes, masks, ids, names, scores):
    """
        take the image and results and apply the mask, box, and Label
    """
    n_instances = boxes.shape[0]
    colors = random_colors(n_instances)

    if not n_instances:
        print('NO INSTANCES TO DISPLAY')
    else:
        assert boxes.shape[0] == masks.shape[-1] == ids.shape[0]

    for i, color in enumerate(colors):
        if not np.any(boxes[i]):
            continue

        y1, x1, y2, x2 = boxes[i]
        label = names[ids[i]]
        score = scores[i] if scores is not None else None
        caption = '{} {:.2f}'.format(label, score) if score else label
        mask = masks[:, :, i]

#         image = apply_mask(image, mask, color)
        image = cv2.rectangle(image, (x1, y1), (x2, y2), color, 2)
        image = cv2.putText(image, caption, (x1, y1),  cv2.FONT_HERSHEY_SIMPLEX, 0.7, color, 2)

    return image

# %%
image_path = str(ROOT_DIR / "video2" / "1.jpg")
image = cv2.imread(image_path)
results = model.detect([image], verbose=1)
r = results[0]
img = display_instances(image, r['rois'], r['masks'], r['class_ids'], class_names, r['scores'])
cv2.imwrite("test.jpg", img)

# %%
VIDEO_SAVE_DIR = str(ROOT_DIR / "video")
capture = cv2.VideoCapture(os.path.join(ROOT_DIR, 'kiev_video.mp4'))
frames = []
frame_count = 0
while True:
    ret, frame = capture.read()
    # Bail out when the video file ends
    if not ret:
        break
    frame_count += 1
    results = model.detect([frame], verbose=1)
    r = results[0]
    name = '{0}.jpg'.format(frame_count)
    name = os.path.join(VIDEO_SAVE_DIR, name)
    frame = display_instances(frame, r['rois'], r['masks'], r['class_ids'], 
                            class_names, r['scores'])
    cv2.imwrite(name, frame)
    print('writing to file:{0}'.format(name))

capture.release()
# Out:
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/1.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/2.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  150.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/3.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/4.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/5.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  150.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/6.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  150.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/7.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/8.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  150.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/9.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/10.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  150.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/11.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/12.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  150.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/13.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/14.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/15.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/16.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/17.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/18.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/19.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/20.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/21.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/22.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/23.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/24.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/25.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/26.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/27.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/28.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/29.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/30.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/31.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/32.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/33.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/34.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/35.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/36.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/37.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/38.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/39.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/40.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/41.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/42.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/43.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/44.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/45.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/46.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/47.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/48.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/49.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/50.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/51.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/52.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/53.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/54.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/55.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/56.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/57.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/58.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/59.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/60.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/61.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/62.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/63.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/64.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/65.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/66.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/67.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/68.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/69.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/70.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/71.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/72.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/73.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/74.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/75.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/76.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/77.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/78.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/79.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/80.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/81.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/82.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/83.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/84.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/85.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/86.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/87.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/88.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/89.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/90.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/91.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/92.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/93.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/94.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/95.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/96.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/97.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/98.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/99.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/100.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/101.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/102.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/103.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/104.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/105.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/106.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/107.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/108.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/109.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/110.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/111.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# ...
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/2476.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/2477.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/2478.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/2479.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/2480.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/2481.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/2482.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/2483.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/2484.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/2485.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/2486.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/2487.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/2488.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/2489.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/2490.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/2491.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/2492.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/2493.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/2494.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/2495.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/2496.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/2497.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/2498.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/2499.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/2500.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/2501.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/2502.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/2503.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/2504.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# writing to file:video/2505.jpg
# Processing 1 images
# image                    shape: (720, 1280, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1280.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-b99e41ed3b06> in <module>
#       9         break
#      10     frame_count += 1
# ---> 11     results = model.detect([frame], verbose=1)
#      12     r = results[0]
#      13     frame = display_instances(frame, r['rois'], r['masks'], r['class_ids'],
#
# ~/BARIS/topic-modeling/newenv/lib/python3.6/site-packages/mrcnn/model.py in detect(self, images, verbose)
#    2500         # Run object detection
#    2501         detections, _, _, mrcnn_mask, _, _, _ =\
# -> 2502             self.keras_model.predict([molded_images, image_metas, anchors], verbose=0)
#    2503         # Process detections
#    2504         results = []
#
# ~/BARIS/topic-modeling/newenv/lib/python3.6/site-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps)
#    1167                                             batch_size=batch_size,
#    1168                                             verbose=verbose,
# -> 1169                                             steps=steps)
#    1170
#    1171     def train_on_batch(self, x, y,
#
# ~/BARIS/topic-modeling/newenv/lib/python3.6/site-packages/keras/engine/training_arrays.py in predict_loop(model, f, ins, batch_size, verbose, steps)
#     292                 ins_batch[i] = ins_batch[i].toarray()
#     293
# --> 294             batch_outs = f(ins_batch)
#     295             batch_outs = to_list(batch_outs)
#     296             if batch_index == 0:
#
# ~/BARIS/topic-modeling/newenv/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# ~/BARIS/topic-modeling/newenv/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# ~/BARIS/topic-modeling/newenv/lib/python3.6/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
# !ls ./video
# Out:
# 1000.jpg  1284.jpg  1567.jpg  184.jpg	2131.jpg  2414.jpg  441.jpg  724.jpg
# 1001.jpg  1285.jpg  1568.jpg  1850.jpg	2132.jpg  2415.jpg  442.jpg  725.jpg
# 1002.jpg  1286.jpg  1569.jpg  1851.jpg	2133.jpg  2416.jpg  443.jpg  726.jpg
# 1003.jpg  1287.jpg  156.jpg   1852.jpg	2134.jpg  2417.jpg  444.jpg  727.jpg
# 1004.jpg  1288.jpg  1570.jpg  1853.jpg	2135.jpg  2418.jpg  445.jpg  728.jpg
_ver, minor_ver, subminor_ver) = (cv2.__version__).split('.')

if int(major_ver)  < 3 :
    fps = video.get(cv2.cv.CV_CAP_PROP_FPS)
    print("Frames per second using video.get(cv2.cv.CV_CAP_PROP_FPS): {0}".format(fps))
else :
    fps = video.get(cv2.CAP_PROP_FPS)
    print("Frames per second using video.get(cv2.CAP_PROP_FPS) : {0}".format(fps))

video.release();
# Out:
# Frames per second using video.get(cv2.CAP_PROP_FPS) : 29.97002997002997

# %%
def make_video(outvid, images=None, fps=30, size=None,
               is_color=True, format="FMP4"):
    """
    Create a video from a list of images.
 
    @param      outvid      output video
    @param      images      list of images to use in the video
    @param      fps         frame per second
    @param      size        size of each frame
    @param      is_color    color
    @param      format      see http://www.fourcc.org/codecs.php
    @return                 see http://opencv-python-tutroals.readthedocs.org/en/latest/py_tutorials/py_gui/py_video_display/py_video_display.html
 
    The function relies on http://opencv-python-tutroals.readthedocs.org/en/latest/.
    By default, the video will have the size of the first image.
    It will resize every image to this size before adding them to the video.
    """
    from cv2 import VideoWriter, VideoWriter_fourcc, imread, resize
    fourcc = VideoWriter_fourcc(*format)
    vid = None
    for image in images:
        if not os.path.exists(image):
            raise FileNotFoundError(image)
        img = imread(image)
        if vid is None:
            if size is None:
                size = img.shape[1], img.shape[0]
            vid = VideoWriter(outvid, fourcc, float(fps), size, is_color)
        if size[0] != img.shape[1] and size[1] != img.shape[0]:
            img = resize(img, size)
        vid.write(img)
    vid.release()
    return vid

import glob
import os

# Directory of images to run detection on
VIDEO_SAVE_DIR = str(ROOT_DIR / "video")

images = list(glob.iglob(os.path.join(VIDEO_SAVE_DIR, '*.*')))

# Sort the images by integer index
images = sorted(images, key=lambda x: float(os.path.split(x)[1][:-3]))

outvid = os.path.join(ROOT_DIR, "kiev_out.mp4")
make_video(outvid, images, fps=30)
# Out:
# <VideoWriter 0x7fec7ffae3b0>

# %%
# !ls -alh
# Out:
# total 1.2G
# drwxrwxr-x  9 Vlad Vlad 4.0K Nov 15 07:52 .
# drwxrwxr-x  8 Vlad Vlad 4.0K Nov 14 11:06 ..
# -rw-rw-r--  1 Vlad Vlad 2.5K Nov 12 14:00 02_generate_person_masks.py
# drwxr-xr-x  5 Vlad Vlad 4.0K Apr 11  2017 DAVIS
# -rw-rw-r--  1 Vlad Vlad 302M Apr 11  2017 DAVIS-2017-test-dev-480p.zip
# -rw-rw-r--  1 Vlad Vlad  81K Nov 13 13:41 file_from_ios.mov
# -rw-rw-r--  1 Vlad Vlad 111M Nov 13 13:45 input_video.MOV
# drwxrwxr-x  2 Vlad Vlad 4.0K Nov 14 21:43 .ipynb_checkpoints
# -rw-rw-r--  1 Vlad Vlad 105M Nov 14 21:59 kiev_video.mp4
# drwxrwxr-x 27 Vlad Vlad 4.0K Nov 15 07:52 logs
# -rw-rw-r--  1 Vlad Vlad 246M Nov 12 15:07 mask_rcnn_coco.h5
# -rw-rw-r--  1 Vlad Vlad  18M Nov 13 14:31 new_video2.avi
# -rw-rw-r--  1 Vlad Vlad 5.6K Nov 14 15:46 new_video3.avi
# -rw-rw-r--  1 Vlad Vlad  18M Nov 13 14:03 new_video.avi
# -rw-rw-r--  1 Vlad Vlad 143M Nov 15 07:53 out.mp4
# drwxrwxr-x  2 Vlad Vlad 4.0K Nov 13 10:52 output
# -rw-rw-r--  1 Vlad Vlad 5.4K Nov 14 22:51 people-segmentation_on_images.ipynb
# -rw-rw-r--  1 Vlad Vlad 3.9M Nov 14 15:42 people_segmentation_on_videos.ipynb
# -rw-rw-r--  1 Vlad Vlad 3.2K Nov 13 11:44 people_segmentation_on_videos.py
# -rw-rw-r--  1 Vlad Vlad  40M Nov 13 15:26 result.avi
# -rw-rw-r--  1 Vlad Vlad 2.8M Nov 15 07:42 Untitled.ipynb
# drwxrwxr-x  2 Vlad Vlad 116K Nov 12 15:45 val2017
# drwxrwxr-x  3 Vlad Vlad  24K Nov 15 07:05 video
# drwxrwxr-x  2 Vlad Vlad  60K Nov 15 07:42 video2
# -rw-rw-r--  1 Vlad Vlad 188M Nov 13 11:38 video.mpg

# %%
from matplotlib import patches
import random
from matplotlib.patches import Polygon
import colorsys

def random_colors(N, bright=True):
    """
    Generate random colors.
    To get visually distinct colors, generate them in HSV space then
    convert to RGB.
    """
    brightness = 1.0 if bright else 0.7
    hsv = [(i / N, 1, brightness) for i in range(N)]
    colors = list(map(lambda c: colorsys.hsv_to_rgb(*c), hsv))
    random.shuffle(colors)
    return colors

def find_contours(array, level, fully_connected='low', positive_orientation='low'):
    array = np.asarray(array, dtype=np.double)
    if array.ndim != 2:
        raise ValueError('Only 2D arrays are supported.')
    level = float(level)
    point_list = _find_contours_cy.iterate_and_store(array, level,
                                                     fully_connected == 'high')
    contours = _assemble_contours(_take_2(point_list))
    if positive_orientation == 'high':
        contours = [c[::-1] for c in contours]
    return contours

def display_instances(image, boxes, masks, class_ids, class_names, name, scores=None, colors=None):

    N = boxes.shape[0]
    if not N:
        print("\n*** No instances to display *** \n")
    else:
        assert boxes.shape[0] == masks.shape[-1] == class_ids.shape[0]

    f, ax = plt.subplots(1)
    f.set_size_inches(10.8, 19.2)
    # Generate random colors
    colors = colors or random_colors(N)

    # Show area outside image boundaries.
#     height, width = image.shape[:2]
#     print(height, width)
#     ax.set_ylim(height)
#     ax.set_xlim(0, width)
    ax.axis('off')

    masked_image = image.astype(np.uint32).copy()
    print(masked_image.shape)
    for i in range(N):
        color = colors[i]

        # Bounding box
        if not np.any(boxes[i]):
            # Skip this instance. Has no bbox. Likely lost in image cropping.
            continue
        y1, x1, y2, x2 = boxes[i]

        p = patches.Rectangle((x1, y1), x2 - x1, y2 - y1, linewidth=4,
                              alpha=0.7, linestyle="dashed",
                              edgecolor=color, facecolor='none')
        ax.add_patch(p)
        class_id = class_ids[i]
        score = scores[i] if scores is not None else None
        label = class_names[class_id]
        caption = "{} {:.3f}".format(label, score) if score else label
        ax.text(x1, y1 - 4, caption, color='w', size=13, backgroundcolor=color)
        
    ax.imshow(masked_image.astype(np.uint8))
#     plt.show()
    f.savefig(name, bbox_inches='tight', dpi=200, frameon=True, pad_inches = 0)

# %%
image_path = str(ROOT_DIR / "val2017" / "0010.jpg")
image = cv2.imread(image_path)
rgb_image = image[:, :, ::-1]
results = model.detect([rgb_image], verbose=1)
r = results[0]
name = 'testtest123.png'
display_instances(rgb_image, r['rois'], r['masks'], r['class_ids'], class_names, name, r['scores'])
# Out:
# Processing 1 images
# image                    shape: (427, 640, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1024.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# (427, 640, 3)

# %%
img = cv2.imread('testtest123.png')
plt.imshow(img)

# %%
image_path = str(ROOT_DIR / "office" / "10.jpg")
image = cv2.imread(image_path)
print(image.shape)
rgb_image = image[:, :, ::-1]
results = model.detect([rgb_image], verbose=1)
r = results[0]
name = 'testtest123.png'
display_instances(rgb_image, r['rois'], r['masks'], r['class_ids'], class_names, name, r['scores'])
# Out:
# (1080, 1920, 3)
# Processing 1 images
# image                    shape: (1080, 1920, 3)       min:    0.00000  max:  246.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  121.30000  float64
# image_metas              shape: (1, 93)               min:    0.00000  max: 1920.00000  float64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
# (1080, 1920, 3)

# %%
img = cv2.imread('testtest123.png')
print(img.shape)
# plt.imshow(img)
# Out:
# (999, 1764, 3)

# %%
# %%time
import cv2
import numpy as np


def random_colors(N):
    np.random.seed(1)
    colors = [tuple(255 * np.random.rand(3)) for _ in range(N)]
    return colors


def apply_mask(image, mask, color, alpha=0.5):
    """apply mask to image"""
    for n, c in enumerate(color):
        image[:, :, n] = np.where(
            mask == 1,
            image[:, :, n] * (1 - alpha) + alpha * c,
            image[:, :, n]
        )
    return image


def display_instances(image, boxes, masks, ids, names, scores):
    """
        take the image and results and apply the mask, box, and Label
    """
    n_instances = boxes.shape[0]
    colors = random_colors(n_instances)

    if not n_instances:
        print('NO INSTANCES TO DISPLAY')
    else:
        assert boxes.shape[0] == masks.shape[-1] == ids.shape[0]

    for i, color in enumerate(colors):
        if not np.any(boxes[i]):
            continue

        y1, x1, y2, x2 = boxes[i]
        label = names[ids[i]]
        score = scores[i] if scores is not None else None
        caption = '{} {:.2f}'.format(label, score) if score else label
        mask = masks[:, :, i]

        image = apply_mask(image, mask, color)
        image = cv2.rectangle(image, (x1, y1), (x2, y2), color, 2)
        image = cv2.putText(image, caption, (x1, y1), cv2.FONT_HERSHEY_COMPLEX, 0.7, color, 2)

    return image


if __name__ == '__main__':
    import os
    import sys
    
    # We use a K80 GPU with 24GB memory, which can fit 3 images.
    batch_size = 3

    VIDEO_SAVE_DIR = os.path.join(ROOT_DIR, "office")
    COCO_MODEL_PATH = os.path.join(ROOT_DIR, "mask_rcnn_coco.h5")

    capture = cv2.VideoCapture(os.path.join(ROOT_DIR, '20181018_170952.mp4'))
    try:
        if not os.path.exists(VIDEO_SAVE_DIR):
            os.makedirs(VIDEO_SAVE_DIR)
    except OSError:
        print ('Error: Creating directory of data')
    frames = []
    frame_count = 0
    # these 2 lines can be removed if you dont have a 1080p camera.
    capture.set(cv2.CAP_PROP_FRAME_WIDTH, 1920)
    capture.set(cv2.CAP_PROP_FRAME_HEIGHT, 1080)

    while True:
        ret, frame = capture.read()
        # Bail out when the video file ends
        if not ret:
            break
        
        # Save each frame of the video to a list
        frame_count += 1
        frames.append(frame)
        print('frame_count :{0}'.format(frame_count))
        if len(frames) == batch_size:
            results = model.detect(frames, verbose=0)
            print('Predicted')
            for i, item in enumerate(zip(frames, results)):
                frame = item[0]
                r = item[1]
                frame = display_instances(
                    frame, r['rois'], r['masks'], r['class_ids'], class_names, r['scores']
                )
                name = '{0}.jpg'.format(frame_count + i - batch_size)
                name = os.path.join(VIDEO_SAVE_DIR, name)
                cv2.imwrite(name, frame)
                print('writing to file:{0}'.format(name))
            # Clear the frames array to start the next batch
            frames = []

    capture.release()
# Out:
# frame_count :1
# frame_count :2
# frame_count :3
# /home/Vlad/BARIS/topic-modeling/newenv/lib/python3.6/site-packages/skimage/transform/_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
# Predicted
# writing to file:./office/0.jpg
# writing to file:./office/1.jpg
# writing to file:./office/2.jpg
# frame_count :4
# frame_count :5
# frame_count :6
# Predicted
# writing to file:./office/3.jpg
# writing to file:./office/4.jpg
# writing to file:./office/5.jpg
# frame_count :7
# frame_count :8
# frame_count :9
# Predicted
# writing to file:./office/6.jpg
# writing to file:./office/7.jpg
# NO INSTANCES TO DISPLAY
# writing to file:./office/8.jpg
# frame_count :10
# frame_count :11
# frame_count :12
# Predicted
# NO INSTANCES TO DISPLAY
# writing to file:./office/9.jpg
# NO INSTANCES TO DISPLAY
# writing to file:./office/10.jpg
# writing to file:./office/11.jpg
# frame_count :13
# frame_count :14
# frame_count :15
# Predicted
# writing to file:./office/12.jpg
# writing to file:./office/13.jpg
# writing to file:./office/14.jpg
# frame_count :16
# frame_count :17
# frame_count :18
# Predicted
# NO INSTANCES TO DISPLAY
# writing to file:./office/15.jpg
# writing to file:./office/16.jpg
# writing to file:./office/17.jpg
# frame_count :19
# frame_count :20
# frame_count :21
# Predicted
# writing to file:./office/18.jpg
# writing to file:./office/19.jpg
# writing to file:./office/20.jpg
# frame_count :22
# frame_count :23
# frame_count :24
# Predicted
# writing to file:./office/21.jpg
# writing to file:./office/22.jpg
# writing to file:./office/23.jpg
# frame_count :25
# frame_count :26
# frame_count :27
# Predicted
# writing to file:./office/24.jpg
# writing to file:./office/25.jpg
# writing to file:./office/26.jpg
# frame_count :28
# frame_count :29
# frame_count :30
# Predicted
# writing to file:./office/27.jpg
# writing to file:./office/28.jpg
# writing to file:./office/29.jpg
# frame_count :31
# frame_count :32
# frame_count :33
# Predicted
# writing to file:./office/30.jpg
# writing to file:./office/31.jpg
# writing to file:./office/32.jpg
# frame_count :34
# frame_count :35
# frame_count :36
# Predicted
# writing to file:./office/33.jpg
# writing to file:./office/34.jpg
# NO INSTANCES TO DISPLAY
# writing to file:./office/35.jpg
# frame_count :37
# frame_count :38
# frame_count :39
# Predicted
# NO INSTANCES TO DISPLAY
# writing to file:./office/36.jpg
# writing to file:./office/37.jpg
# writing to file:./office/38.jpg
# frame_count :40
# frame_count :41
# frame_count :42
# Predicted
# writing to file:./office/39.jpg
# writing to file:./office/40.jpg
# NO INSTANCES TO DISPLAY
# writing to file:./office/41.jpg
# frame_count :43
# frame_count :44
# frame_count :45
# Predicted
# writing to file:./office/42.jpg
# writing to file:./office/43.jpg
# writing to file:./office/44.jpg
# frame_count :46
# frame_count :47
# frame_count :48
# Predicted
# writing to file:./office/45.jpg
# writing to file:./office/46.jpg
# writing to file:./office/47.jpg
# frame_count :49
# frame_count :50
# frame_count :51
# Predicted
# writing to file:./office/48.jpg
# writing to file:./office/49.jpg
# writing to file:./office/50.jpg
# frame_count :52
# frame_count :53
# frame_count :54
# Predicted
# writing to file:./office/51.jpg
# NO INSTANCES TO DISPLAY
# writing to file:./office/52.jpg
# writing to file:./office/53.jpg
# frame_count :55
# frame_count :56
# frame_count :57
# Predicted
# writing to file:./office/54.jpg
# writing to file:./office/55.jpg
# writing to file:./office/56.jpg
# frame_count :58
# frame_count :59
# frame_count :60
# Predicted
# writing to file:./office/57.jpg
# writing to file:./office/58.jpg
# writing to file:./office/59.jpg
# frame_count :61
# frame_count :62
# frame_count :63
# Predicted
# writing to file:./office/60.jpg
# writing to file:./office/61.jpg
# writing to file:./office/62.jpg
# frame_count :64
# frame_count :65
# frame_count :66
# Predicted
# writing to file:./office/63.jpg
# writing to file:./office/64.jpg
# writing to file:./office/65.jpg
# frame_count :67
# frame_count :68
# frame_count :69
# Predicted
# writing to file:./office/66.jpg
# writing to file:./office/67.jpg
# writing to file:./office/68.jpg
# frame_count :70
# frame_count :71
# frame_count :72
# Predicted
# writing to file:./office/69.jpg
# writing to file:./office/70.jpg
# writing to file:./office/71.jpg
# frame_count :73
# frame_count :74
# frame_count :75
# Predicted
# writing to file:./office/72.jpg
# writing to file:./office/73.jpg
# writing to file:./office/74.jpg
# frame_count :76
# frame_count :77
# frame_count :78
# Predicted
# writing to file:./office/75.jpg
# writing to file:./office/76.jpg
# writing to file:./office/77.jpg
# frame_count :79
# frame_count :80
# frame_count :81
# Predicted
# writing to file:./office/78.jpg
# writing to file:./office/79.jpg
# writing to file:./office/80.jpg
# frame_count :82
# frame_count :83
# frame_count :84
# Predicted
# writing to file:./office/81.jpg
# writing to file:./office/82.jpg
# writing to file:./office/83.jpg
# frame_count :85
# frame_count :86
# frame_count :87
# Predicted
# writing to file:./office/84.jpg
# writing to file:./office/85.jpg
# writing to file:./office/86.jpg
# frame_count :88
# frame_count :89
# frame_count :90
# Predicted
# writing to file:./office/87.jpg
# writing to file:./office/88.jpg
# writing to file:./office/89.jpg
# frame_count :91
# frame_count :92
# frame_count :93
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/BARIS/topic-modeling/newenv/lib/python3.6/site-packages/mrcnn/model.py in detect(self, images, verbose)
#    2479
#    2480         # Mold inputs to format expected by the neural network
# -> 2481         molded_images, image_metas, windows = self.mold_inputs(images)
#    2482
#    2483         # Validate image sizes
#
# ~/BARIS/topic-modeling/newenv/lib/python3.6/site-packages/mrcnn/model.py in mold_inputs(self, images)
#    2378                 max_dim=self.config.IMAGE_MAX_DIM,
#    2379                 mode=self.config.IMAGE_RESIZE_MODE)
# -> 2380             molded_image = mold_image(molded_image, self.config)
#    2381             # Build image_meta
#    2382             image_meta = compose_image_meta(
#
# ~/BARIS/topic-modeling/newenv/lib/python3.6/site-packages/mrcnn/model.py in mold_image(images, config)
#    2779     colors in RGB order.
#    2780     """
# -> 2781     return images.astype(np.float32) - config.MEAN_PIXEL
#    2782
#    2783
#
# KeyboardInterrupt:
